# %% [markdown]
# Q1. Explain GET and POST methods.

# %% [raw]
# 'GET' method is used to retrieve data from the server. It is used when data is not sensititve.
# 'POST' method enables users to send data over to the server. It is used when data is sensitive. Unlike 'GET', the onformation won't be diaplyed in the URL.

# %% [markdown]
# Q2. Why is request used in Flask?

# %% [raw]
# The request object in Flask helps in sending and receiving operations from user's browser to the server and process the data from the server.

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %% [raw]
# redirect() is used in Flask to redirect to another route when an action is performed.

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %% [raw]
# Templates are folders where our html files are stored. render_template() function is used to display those html files at specified routes.

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import Flask, render_template, request, jsonify

app = Flask(__name__,template_folder="template1")

@app.route("/")
def home_page():
    return render_template("simple_api.html")

@app.route("/input", methods = ['POST'])
def func():
    if(request.method == 'POST'):
        ch = request.json['choice']
        
    return jsonify(ch)

if __name__ == "__main__":
    app.run("0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.70.106.29:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/Aug/2023 11:22:25] "POST /input HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)
