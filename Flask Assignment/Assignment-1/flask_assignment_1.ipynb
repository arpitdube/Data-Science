# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [raw]
# Flask is a python framework used for web development. Advantages of flask are:-
# 1) It is a lightweight framework.
# 2) Provides flexibility to the developers.
# 3) It is suitable for small projects.
# 4) Support for secure cookies
# 5) It has integrated support for unit testing.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello World!!</h1>"

if __name__ == "__main__":
    app.run("0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.70.106.29:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/Aug/2023 11:24:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2023 11:24:02] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [raw]
# App routing in Flask refers to mapping URLs with their functions. We use app routes to show the specific output (web page) for specific URLs.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask, render_template

app1 = Flask(__name__,template_folder="template")

@app1.route("/")
def home_func():
    return render_template("index.html")
    
@app1.route("/welcome")
def message():
    return "Welcome to ABC Corporation"

if __name__ == "__main__":
    app1.run("0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.70.106.29:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [16/Aug/2023 22:22:57] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %%
# url_for() function is used for URL building in FLask.

from flask import Flask, render_template

app3 = Flask(__name__,template_folder="template")

@app3.route("/")
def home():
    return render_template("index2.html")

@app3.route("/ind")
def ind():
    return "<h1>This is index page</h1>"
    

if __name__ == "__main__":
    app3.run('0.0.0.0')
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.70.106.29:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/Aug/2023 13:48:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2023 13:48:53] "GET /ind HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
