# %%
import seaborn as sns

# %% [markdown]
# Q1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [raw]
# 1) Scatter Plot (sns.scatterplot) -> It is used to show the relationship between two numerical variables, typically for exploring correlations or patterns in the data.
# 2) Histogrm (sns.displot) -> It is used to display the distribution of a single numerical variable.
# 3) Relational Plot (sns.relplot) -> It is used for creating relationship plots, which are high-level figures for visualizing statistical relationships between variables.
# 4) Cat Plot (sns.catplot) -> It is used for visualizing the distribution and relationships between variables that are categorical in nature.
# 5) Joint Plot (sns.jointplot) -> It combines multiple plots in a single figure to help us explore the relationships between two numerical variables.

# %% [markdown]
# Q2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.

# %%
fmri = sns.load_dataset('fmri')

# %%
sns.lineplot(x = fmri.timepoint,y = fmri.signal)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# Q3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.boxplot(x = titanic.pclass,y = titanic.age)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x = titanic.pclass,y = titanic.fare)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# Q4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
dia = sns.load_dataset('diamonds')

# %%
sns.displot(data = dia, x = 'price',hue = 'cut')

# %% [markdown]
# Q5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(data = iris,hue = 'species')

# %% [markdown]
# Q6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights = sns.load_dataset('flights')

# %%
flights_pivot = flights.pivot_table(index="month",columns="year",values="passengers",aggfunc="sum")

# %%
sns.heatmap(flights_pivot,annot=True,fmt="d",cmap="coolwarm",linewidths=.5)
# Out:
# <Axes: xlabel='year', ylabel='month'>
